# %%
import pandas as pd

# %%
bike_cl = pd.read_csv('data/HSIP_Bicycle_Crash_Clusters_2007__2016.csv')

# %%
bike_cl.head()
# Out:
#    OBJECTID  Id  CrashCount                             GroupCode  \
# 0         1   0           9  4eb835e1-64ef-4e91-8cb4-4a1d58353453
# 1         2   0          10  9ed432a9-3f92-4da4-b8ab-712605e3a850
# 2         3   0          12  61d1661e-9b6e-44f4-b71a-9e93e32154a5
# 3         4   0          31  90edb956-1b7f-4e1b-91b1-8c496372cdd0
# 4         5   0           6  e31890be-4081-465c-bb41-8ad146d5aa57
#
#           L1STREET            L2STREET  L1STREETRT  L2STREETRT  \
# 0      MAIN STREET   PLAINFIELD STREET  L151462 NB    SR20A EB
# 1      MAIN STREET  LYNN FELLS PARKWAY     N344 NB    N1285 NB
# 2  PROSPECT STREET      HARVARD STREET     N327 NB    N2417 EB
# 3    BEACON STREET        UNION STREET     N075 NB  L114589 EB
# 4                        WINTER STREET    SR110 WB     SR97 NB
#
#          FC1STREET           FC2STREET  ... EPDO_INJUR   TOP_5_TOWN TOP_5_RPA  \
# 0      MAIN STREET   PLAINFIELD STREET  ...        149  SPRINGFIELD      PVPC
# ...

# %%
bike_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OBJECTID          129 non-null    int64
#  1   Id                129 non-null    int64
#  2   CrashCount        129 non-null    int64
#  3   GroupCode         129 non-null    object
#  4   L1STREET          129 non-null    object
#  5   L2STREET          129 non-null    object
#  6   L1STREETRT        129 non-null    object
#  7   L2STREETRT        129 non-null    object
#  8   FC1STREET         129 non-null    object
#  9   FC2STREET         129 non-null    object
#  10  FC1STREETR        129 non-null    object
#  11  FC2STREETR        129 non-null    object
#  12  RPAS              129 non-null    object
#  13  TOWNS             129 non-null    object
#  14  MASSDOT           129 non-null    object
#  15  NUM_K_A           129 non-null    int64
# ...

# %%
ped_cl = pd.read_csv('data/HSIP_Pedestrian_Crash_Clusters_2007__2016.csv')

# %%
ped_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OBJECTID          189 non-null    int64
#  1   Id                189 non-null    int64
#  2   CrashCount        189 non-null    int64
#  3   GroupCode         189 non-null    object
#  4   L1STREET          189 non-null    object
#  5   L2STREET          189 non-null    object
#  6   L1STREETRT        189 non-null    object
#  7   L2STREETRT        189 non-null    object
#  8   FC1STREET         189 non-null    object
#  9   FC2STREET         189 non-null    object
#  10  FC1STREETR        189 non-null    object
#  11  FC2STREETR        189 non-null    object
#  12  RPAS              189 non-null    object
#  13  TOWNS             189 non-null    object
#  14  MASSDOT           189 non-null    object
#  15  NUM_K_A           189 non-null    int64
# ...
