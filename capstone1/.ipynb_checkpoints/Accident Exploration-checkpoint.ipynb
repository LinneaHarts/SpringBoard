# %%
import pandas as pd

# %%
bike_df = pd.read_excel('capstone1/data/Final_Bike_Collision_Database.xlsx')
bike_df.head()
# Out:
#          ID    YEAR       DATE  DAY_WEEK             TIME TYPE   SOURCE  \
# 0     B1001  2009.0 2009-01-09    Friday  14:24:59.962000  BVA     E911
# 1     B1002  2009.0 2009-01-23    Friday  16:43:59.981000  BVA  ON-SITE
# 2     B1003  2009.0 2009-01-25    Sunday         12:45:00  BVA     E911
# 3     B1004  2009.0 2009-02-05  Thursday  05:05:00.038000  BVA     E911
# 4     B1005  2009.0 2009-02-08    Sunday  08:37:00.019000  BVA     E911
# ...     ...     ...        ...       ...              ...  ...      ...
# 1803  B2815     NaN        NaT       NaN              NaN  NaN     E911
# 1804  B2817  2012.0 2012-10-05       NaN         18:45:00  NaN  WALK-IN
# 1805  B2818  2012.0 2012-10-20       NaN         19:53:00  NaN     E911
# 1806  B2819     NaN        NaT       NaN              NaN  NaN     E911
# 1807  B2820     NaN        NaT       NaN              NaN  NaN      NaN
#
#              XFINAL            Xkm        YFINAL  ...  TaxiFinal hitrunfina  \
# ...

# %%
car_df = pd.read_csv('capstone1/data/US_Accidents_Dec19.csv')
car_df.head()
# Out:
#     ID    Source    TMC  Severity           Start_Time             End_Time  \
# 0  A-1  MapQuest  201.0         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  MapQuest  201.0         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  MapQuest  201.0         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  MapQuest  201.0         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  MapQuest  201.0         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0  39.865147 -84.058723      NaN      NaN  ...       False   False  False
# 1  39.928059 -82.831184      NaN      NaN  ...       False   False  False
# 2  39.063148 -84.032608      NaN      NaN  ...       False   False  False
# 3  39.747753 -84.205582      NaN      NaN  ...       False   False  False
# 4  39.627781 -84.188354      NaN      NaN  ...       False   False  False
#
# ...
